# %% [markdown]
# <a href="https://colab.research.google.com/github/walidbayoud/Stock_Price_Prediction_LSTM/blob/main/Stock_Price_Prediction_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Description:
# This program uses an artificial recurrent neural network called Long Short Term Memory (LSTM) to predict the closing stock price of a corporation (MSFT) using the past days' stock price.

# %% [markdown]
# # Stock Price Prediction with LSTM – Research-Oriented Version
#
# **Research question:**
# Do LSTM-based models provide a statistically meaningful improvement over simple time-series baselines for short-term stock price prediction?
#
# **Main elements in this notebook:**
# - Clear train / validation / test split on a time axis
# - LSTM model for regression
# - Naive time-series baseline for comparison
# - Proper error metrics (RMSE, MAE, MAPE, directional accuracy)
# - Plots that compare predictions vs. actual prices

# %% [markdown]
# ### Importring Data

# %%
#Import the libraries
import pandas as pd

#Get Data from the csv file
df = pd.read_csv('data/MSFT.csv')
#Display Data
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1986-03-13    0.088542    0.101563    0.088542    0.097222    0.060163
# 1     1986-03-14    0.097222    0.102431    0.097222    0.100694    0.062311
# 2     1986-03-17    0.100694    0.103299    0.100694    0.102431    0.063386
# 3     1986-03-18    0.102431    0.103299    0.098958    0.099826    0.061774
# 4     1986-03-19    0.099826    0.100694    0.097222    0.098090    0.060700
# ...          ...         ...         ...         ...         ...         ...
# 9598  2024-04-15  426.600006  426.820007  413.429993  413.640015  413.640015
# 9599  2024-04-16  414.570007  418.399994  413.730011  414.579987  414.579987
# 9600  2024-04-17  417.250000  418.880005  410.329987  411.839996  411.839996
# 9601  2024-04-18  410.630005  411.890015  403.950012  404.269989  404.269989
# 9602  2024-04-19  404.029999  405.480011  397.769989  399.119995  399.119995
#
#           Volume
# 0     1031788800
# 1      308160000
# 2      133171200
# 3       67766400
# 4       47894400
# ...          ...
# 9598    20273500
# 9599    16765600
# 9600    15855500
# 9601    21029900
# 9602    29021678
#
# [9603 rows x 7 columns]

# %% [markdown]
# ## Processing Data

# %%
#Limit the columns to only Date and Close
df = df[['Date','Close']]
df
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9598  2024-04-15  413.640015
# 9599  2024-04-16  414.579987
# 9600  2024-04-17  411.839996
# 9601  2024-04-18  404.269989
# 9602  2024-04-19  399.119995
#
# [9603 rows x 2 columns]

# %%
#Turn the Date strings to datetime
df['Date'] = pd.to_datetime(df['Date'])
df['Date']
# Out:
# /var/folders/fw/35zr31d95yb51prj11ykzxbh0000gn/T/ipykernel_90232/4145630550.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = pd.to_datetime(df['Date'])
# 0      1986-03-13
# 1      1986-03-14
# 2      1986-03-17
# 3      1986-03-18
# 4      1986-03-19
#           ...
# 9598   2024-04-15
# 9599   2024-04-16
# 9600   2024-04-17
# 9601   2024-04-18
# 9602   2024-04-19
# Name: Date, Length: 9603, dtype: datetime64[ns]

# %%
#Deleting the actula indexe and replace it by Date
df.index=df.pop('Date')
df
# Out:
#                  Close
# Date
# 1986-03-13    0.097222
# 1986-03-14    0.100694
# 1986-03-17    0.102431
# 1986-03-18    0.099826
# 1986-03-19    0.098090
# ...                ...
# 2024-04-15  413.640015
# 2024-04-16  414.579987
# 2024-04-17  411.839996
# 2024-04-18  404.269989
# 2024-04-19  399.119995
#
# [9603 rows x 1 columns]

# %%
#visualizing the processed Data
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
plt.plot(df.index, df['Close'])

# %%
#Getting the Data ready to Train
import pandas as pd
import numpy as np


def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
    first_date = pd.to_datetime(first_date_str)
    last_date = pd.to_datetime(last_date_str)

    target_date = first_date

    dates = []
    X, Y = [], []

    while True:
        df_subset = dataframe.loc[:target_date].tail(n + 1)

        if len(df_subset) != n + 1:
            print(f'Error: Window of size {n} is too large for date {target_date}')
            return

        values = df_subset['Close'].to_numpy()
        x, y = values[:-1], values[-1]

        dates.append(target_date)
        X.append(x)
        Y.append(y)

        next_date = target_date + pd.Timedelta(days=1)  # Change to daily intervals

        if next_date > last_date:
            break

        target_date = next_date

    ret_df = pd.DataFrame({})
    ret_df['Target Date'] = dates

    for i in range(n):
        ret_df[f'Target-{n - i}'] = [x[i] for x in X]

    ret_df['Target'] = Y

    return ret_df

# Test the function
windowed_df = df_to_windowed_df(df, '2022-11-01', '2023-11-01', n=3)
print(windowed_df)
# Out:
#     Target Date    Target-3    Target-2    Target-1      Target
# 0    2022-11-01  226.750000  235.869995  232.130005  228.169998
# 1    2022-11-02  235.869995  232.130005  228.169998  220.100006
# 2    2022-11-03  232.130005  228.169998  220.100006  214.250000
# 3    2022-11-04  228.169998  220.100006  214.250000  221.389999
# 4    2022-11-05  228.169998  220.100006  214.250000  221.389999
# ..          ...         ...         ...         ...         ...
# 361  2023-10-28  330.529999  340.670013  327.890015  329.809998
# 362  2023-10-29  330.529999  340.670013  327.890015  329.809998
# 363  2023-10-30  340.670013  327.890015  329.809998  337.309998
# 364  2023-10-31  327.890015  329.809998  337.309998  338.109985
# 365  2023-11-01  329.809998  337.309998  338.109985  346.070007
#
# [366 rows x 5 columns]

# %%
#Reshape the Data

def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np= windowed_dataframe.to_numpy()

  dates =df_as_np[:,0]

  middle_matrix = df_as_np[:,1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y= df_as_np[:,-1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y=windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((366,), (366, 3, 1), (366,))

# %%
#Split the Data into training,validation, and testing Data

q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]

dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train,y_train)
plt.plot(dates_val,y_val)
plt.plot(dates_test,y_test)

plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))  # Year-month format
plt.gca().xaxis.set_major_locator(mdates.YearLocator())  # Show tick for every year

plt.xlabel('Date')
plt.ylabel('Close Price')
plt.title('Close Price Over Time')

plt.legend(['Train', 'Validation', 'Test'])

plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent overlap

plt.show()

# %%
#Creating the Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3,1)),
                    layers.LSTM(64),
                    layers.Dense(32,activation='relu'),
                    layers.Dense(32,activation='relu'),
                    layers.Dense(1)])
model.compile(loss='mse',
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])
model.fit(X_train, y_train, validation_data=(X_val,y_val), epochs=100)
# Out:
# Epoch 1/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 79715.5000 - mean_absolute_error: 279.5119 - val_loss: 106469.4609 - val_mean_absolute_error: 326.2382
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 81672.4922 - mean_absolute_error: 282.9177 - val_loss: 105978.8125 - val_mean_absolute_error: 325.4853
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 80771.7500 - mean_absolute_error: 281.4557 - val_loss: 105264.1406 - val_mean_absolute_error: 324.3856
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 80920.8594 - mean_absolute_error: 281.6774 - val_loss: 103926.6562 - val_mean_absolute_error: 322.3175
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 79526.9688 - mean_absolute_error: 279.1495 - val_loss: 102081.0234 - val_mean_absolute_error: 319.4414
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 78075.1406 - mean_absolute_error: 276.6480 - val_loss: 99027.5078 - val_mean_absolute_error: 314.6256
# Epoch 7/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 74611.2578 - mean_absolute_error: 269.9953 - val_loss: 95269.3125 - val_mean_absolute_error: 308.5953
# Epoch 8/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 70041.0859 - mean_absolute_error: 261.7249 - val_loss: 90588.6641 - val_mean_absolute_error: 300.9161
# Epoch 9/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 68412.7422 - mean_absolute_error: 258.4972 - val_loss: 84693.7344 - val_mean_absolute_error: 290.9562
# Epoch 10/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 62169.2500 - mean_absolute_error: 246.0789 - val_loss: 77536.7266 - val_mean_absolute_error: 278.3857
# Epoch 11/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 54553.3086 - mean_absolute_error: 230.2132 - val_loss: 68919.1250 - val_mean_absolute_error: 262.4518
# Epoch 12/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 46844.9805 - mean_absolute_error: 212.4997 - val_loss: 58324.6836 - val_mean_absolute_error: 241.4261
# Epoch 13/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 38128.1875 - mean_absolute_error: 191.2709 - val_loss: 48290.1758 - val_mean_absolute_error: 219.6635
# Epoch 14/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29545.4453 - mean_absolute_error: 167.5662 - val_loss: 38229.4023 - val_mean_absolute_error: 195.4259
# Epoch 15/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 23547.4141 - mean_absolute_error: 147.8743 - val_loss: 28682.1152 - val_mean_absolute_error: 169.2454
# Epoch 16/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 16292.0850 - mean_absolute_error: 121.0501 - val_loss: 20420.9941 - val_mean_absolute_error: 142.7686
# Epoch 17/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10722.6494 - mean_absolute_error: 94.7696 - val_loss: 13748.0605 - val_mean_absolute_error: 117.0895
# Epoch 18/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6503.3853 - mean_absolute_error: 69.9160 - val_loss: 8798.0957 - val_mean_absolute_error: 93.5947
# Epoch 19/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3588.9409 - mean_absolute_error: 47.1210 - val_loss: 5553.2393 - val_mean_absolute_error: 74.2639
# Epoch 20/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2562.6282 - mean_absolute_error: 40.5883 - val_loss: 3618.9832 - val_mean_absolute_error: 59.8403
# Epoch 21/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1761.9091 - mean_absolute_error: 36.3226 - val_loss: 2584.6853 - val_mean_absolute_error: 50.4635
# Epoch 22/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1651.1312 - mean_absolute_error: 35.8519 - val_loss: 2015.1470 - val_mean_absolute_error: 44.4638
# Epoch 23/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1487.5815 - mean_absolute_error: 34.6784 - val_loss: 1820.9404 - val_mean_absolute_error: 42.2235
# Epoch 24/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1663.5990 - mean_absolute_error: 36.9898 - val_loss: 1824.6493 - val_mean_absolute_error: 42.2674
# Epoch 25/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1511.9420 - mean_absolute_error: 34.7106 - val_loss: 1871.7847 - val_mean_absolute_error: 42.8213
# Epoch 26/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1659.7332 - mean_absolute_error: 37.0099 - val_loss: 1970.5958 - val_mean_absolute_error: 43.9600
# Epoch 27/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1609.1478 - mean_absolute_error: 36.1357 - val_loss: 2002.5883 - val_mean_absolute_error: 44.3224
# Epoch 28/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1567.0653 - mean_absolute_error: 35.8426 - val_loss: 1954.2278 - val_mean_absolute_error: 43.7734
# Epoch 29/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1590.6719 - mean_absolute_error: 36.2367 - val_loss: 1902.9785 - val_mean_absolute_error: 43.1840
# Epoch 30/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1549.7720 - mean_absolute_error: 35.4485 - val_loss: 1967.7080 - val_mean_absolute_error: 43.9271
# Epoch 31/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1642.2233 - mean_absolute_error: 36.6764 - val_loss: 2055.4038 - val_mean_absolute_error: 44.9137
# Epoch 32/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1565.2118 - mean_absolute_error: 35.5614 - val_loss: 2082.7107 - val_mean_absolute_error: 45.2172
# Epoch 33/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1614.6919 - mean_absolute_error: 36.1446 - val_loss: 2072.4226 - val_mean_absolute_error: 45.1049
# Epoch 34/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1617.5193 - mean_absolute_error: 36.0683 - val_loss: 2154.6685 - val_mean_absolute_error: 46.0148
# Epoch 35/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1537.2059 - mean_absolute_error: 35.1952 - val_loss: 2067.2544 - val_mean_absolute_error: 45.0600
# Epoch 36/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1545.0029 - mean_absolute_error: 35.3483 - val_loss: 1920.1195 - val_mean_absolute_error: 43.4011
# Epoch 37/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1466.7760 - mean_absolute_error: 34.2920 - val_loss: 2162.2651 - val_mean_absolute_error: 46.1355
# Epoch 38/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1323.5442 - mean_absolute_error: 31.7562 - val_loss: 2143.8398 - val_mean_absolute_error: 45.9801
# Epoch 39/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1111.7031 - mean_absolute_error: 28.4630 - val_loss: 1231.8898 - val_mean_absolute_error: 34.6143
# Epoch 40/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1101.5657 - mean_absolute_error: 30.0778 - val_loss: 1478.1619 - val_mean_absolute_error: 38.0579
# Epoch 41/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 948.3783 - mean_absolute_error: 26.8763 - val_loss: 1348.8425 - val_mean_absolute_error: 36.3823
# Epoch 42/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 782.3651 - mean_absolute_error: 24.4786 - val_loss: 889.8760 - val_mean_absolute_error: 29.3857
# Epoch 43/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 600.7080 - mean_absolute_error: 21.5877 - val_loss: 680.4880 - val_mean_absolute_error: 25.5716
# Epoch 44/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 479.7711 - mean_absolute_error: 19.0476 - val_loss: 613.1470 - val_mean_absolute_error: 24.2997
# Epoch 45/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 361.9574 - mean_absolute_error: 16.0472 - val_loss: 537.0403 - val_mean_absolute_error: 22.7202
# Epoch 46/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 276.1020 - mean_absolute_error: 13.3028 - val_loss: 277.8929 - val_mean_absolute_error: 16.0145
# Epoch 47/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 226.4184 - mean_absolute_error: 12.7582 - val_loss: 178.4505 - val_mean_absolute_error: 12.5597
# Epoch 48/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 155.2024 - mean_absolute_error: 9.9898 - val_loss: 123.1512 - val_mean_absolute_error: 10.1833
# Epoch 49/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 126.8644 - mean_absolute_error: 9.2698 - val_loss: 130.5169 - val_mean_absolute_error: 10.6388
# Epoch 50/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 95.7091 - mean_absolute_error: 7.3411 - val_loss: 78.6812 - val_mean_absolute_error: 7.8747
# Epoch 51/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 68.4831 - mean_absolute_error: 6.4927 - val_loss: 27.8063 - val_mean_absolute_error: 4.4657
# Epoch 52/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 55.3752 - mean_absolute_error: 6.0436 - val_loss: 17.4320 - val_mean_absolute_error: 3.2422
# Epoch 53/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 68.5869 - mean_absolute_error: 6.9777 - val_loss: 115.1707 - val_mean_absolute_error: 10.0695
# Epoch 54/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 98.7094 - mean_absolute_error: 8.5013 - val_loss: 15.7785 - val_mean_absolute_error: 3.1428
# Epoch 55/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 46.3054 - mean_absolute_error: 5.5601 - val_loss: 20.4660 - val_mean_absolute_error: 3.7543
# Epoch 56/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 46.4414 - mean_absolute_error: 5.3627 - val_loss: 15.6447 - val_mean_absolute_error: 3.2115
# Epoch 57/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 47.0168 - mean_absolute_error: 5.5901 - val_loss: 15.1823 - val_mean_absolute_error: 3.1417
# Epoch 58/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 42.3366 - mean_absolute_error: 5.1232 - val_loss: 16.6549 - val_mean_absolute_error: 3.3995
# Epoch 59/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 34.4365 - mean_absolute_error: 4.6570 - val_loss: 21.5563 - val_mean_absolute_error: 3.8830
# Epoch 60/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 36.1623 - mean_absolute_error: 4.8507 - val_loss: 15.4016 - val_mean_absolute_error: 3.1870
# Epoch 61/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 34.6848 - mean_absolute_error: 4.8288 - val_loss: 14.9022 - val_mean_absolute_error: 3.2081
# Epoch 62/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 27.5877 - mean_absolute_error: 4.2259 - val_loss: 17.4388 - val_mean_absolute_error: 3.4783
# Epoch 63/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 33.5506 - mean_absolute_error: 4.6630 - val_loss: 14.7161 - val_mean_absolute_error: 3.2137
# Epoch 64/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.9865 - mean_absolute_error: 4.3705 - val_loss: 18.1089 - val_mean_absolute_error: 3.5533
# Epoch 65/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 32.7826 - mean_absolute_error: 4.6030 - val_loss: 13.4524 - val_mean_absolute_error: 2.9684
# Epoch 66/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 31.1095 - mean_absolute_error: 4.4056 - val_loss: 17.3675 - val_mean_absolute_error: 3.4777
# Epoch 67/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.8222 - mean_absolute_error: 4.3383 - val_loss: 18.3982 - val_mean_absolute_error: 3.5889
# Epoch 68/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.5551 - mean_absolute_error: 4.3805 - val_loss: 16.3171 - val_mean_absolute_error: 3.4060
# Epoch 69/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 36.2225 - mean_absolute_error: 4.8222 - val_loss: 14.8181 - val_mean_absolute_error: 3.1586
# Epoch 70/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 33.3560 - mean_absolute_error: 4.6955 - val_loss: 38.0639 - val_mean_absolute_error: 5.1495
# Epoch 71/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 33.5651 - mean_absolute_error: 4.6347 - val_loss: 13.2935 - val_mean_absolute_error: 2.9681
# Epoch 72/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 31.7593 - mean_absolute_error: 4.4501 - val_loss: 40.8693 - val_mean_absolute_error: 5.3725
# Epoch 73/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 32.4052 - mean_absolute_error: 4.5598 - val_loss: 13.6301 - val_mean_absolute_error: 2.9694
# Epoch 74/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30.0764 - mean_absolute_error: 4.2035 - val_loss: 14.5135 - val_mean_absolute_error: 3.1003
# Epoch 75/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 27.1256 - mean_absolute_error: 4.1066 - val_loss: 38.7319 - val_mean_absolute_error: 5.1892
# Epoch 76/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 30.1470 - mean_absolute_error: 4.3601 - val_loss: 13.2185 - val_mean_absolute_error: 3.0232
# Epoch 77/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 34.9520 - mean_absolute_error: 4.5389 - val_loss: 13.3410 - val_mean_absolute_error: 3.0718
# Epoch 78/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 37.8129 - mean_absolute_error: 5.0842 - val_loss: 17.3532 - val_mean_absolute_error: 3.4711
# Epoch 79/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 39.3003 - mean_absolute_error: 5.0570 - val_loss: 14.4819 - val_mean_absolute_error: 3.2476
# Epoch 80/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 27.2492 - mean_absolute_error: 4.1363 - val_loss: 29.7450 - val_mean_absolute_error: 4.4899
# Epoch 81/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 35.2975 - mean_absolute_error: 4.6993 - val_loss: 20.6064 - val_mean_absolute_error: 3.7934
# Epoch 82/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 25.9578 - mean_absolute_error: 4.0226 - val_loss: 32.8405 - val_mean_absolute_error: 4.8912
# Epoch 83/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 49.9507 - mean_absolute_error: 5.4862 - val_loss: 15.4014 - val_mean_absolute_error: 3.3491
# Epoch 84/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 28.3230 - mean_absolute_error: 4.2107 - val_loss: 33.8884 - val_mean_absolute_error: 4.8184
# Epoch 85/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 27.0443 - mean_absolute_error: 3.9552 - val_loss: 20.1135 - val_mean_absolute_error: 3.7392
# Epoch 86/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 28.8768 - mean_absolute_error: 4.2081 - val_loss: 15.5535 - val_mean_absolute_error: 3.3752
# Epoch 87/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 27.0545 - mean_absolute_error: 3.9766 - val_loss: 14.8983 - val_mean_absolute_error: 3.1235
# Epoch 88/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 25.5161 - mean_absolute_error: 3.9146 - val_loss: 14.0696 - val_mean_absolute_error: 2.9815
# Epoch 89/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 23.3522 - mean_absolute_error: 3.7078 - val_loss: 46.5079 - val_mean_absolute_error: 5.7933
# Epoch 90/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.3763 - mean_absolute_error: 4.4045 - val_loss: 27.5869 - val_mean_absolute_error: 4.2761
# Epoch 91/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 26.0464 - mean_absolute_error: 4.0998 - val_loss: 13.3013 - val_mean_absolute_error: 3.0166
# Epoch 92/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 26.0575 - mean_absolute_error: 3.9519 - val_loss: 13.5847 - val_mean_absolute_error: 2.9577
# Epoch 93/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.3184 - mean_absolute_error: 4.1658 - val_loss: 15.3757 - val_mean_absolute_error: 3.1775
# Epoch 94/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 26.1927 - mean_absolute_error: 4.0313 - val_loss: 13.3786 - val_mean_absolute_error: 2.9855
# Epoch 95/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 29.7426 - mean_absolute_error: 4.1851 - val_loss: 14.0143 - val_mean_absolute_error: 3.1895
# Epoch 96/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 35.8686 - mean_absolute_error: 4.6809 - val_loss: 45.9878 - val_mean_absolute_error: 5.7457
# Epoch 97/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 35.3086 - mean_absolute_error: 4.7631 - val_loss: 15.9734 - val_mean_absolute_error: 3.2821
# Epoch 98/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 34.3941 - mean_absolute_error: 4.5293 - val_loss: 26.9918 - val_mean_absolute_error: 4.3897
# Epoch 99/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 34.2103 - mean_absolute_error: 4.5162 - val_loss: 14.0544 - val_mean_absolute_error: 2.9811
# Epoch 100/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 23.4541 - mean_absolute_error: 3.8948 - val_loss: 15.7387 - val_mean_absolute_error: 3.2541

# %%
#training the Model
train_predictions = model.predict(X_train).flatten()
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observation'])
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))  # Year-month format
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observation'])
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
test_predictions = model.predict(X_test).flatten()
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))  # Year-month format
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Test Predictions', 'Test Observation'])
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

plt.figure(figsize=(12, 6))


plt.plot(dates_train, train_predictions, linestyle='--', color='blue', linewidth=2, alpha=0.7)
plt.plot(dates_train, y_train, linestyle='-', color='blue', linewidth=2, alpha=0.7)

plt.plot(dates_val, val_predictions, linestyle='--', color='orange', linewidth=2, alpha=0.7)
plt.plot(dates_val, y_val, linestyle='-', color='orange', linewidth=2, alpha=0.7)

plt.plot(dates_test, test_predictions, linestyle='--', color='green', linewidth=2, alpha=0.7)
plt.plot(dates_test, y_test, linestyle='-', color='green', linewidth=2, alpha=0.7)

plt.xlabel('Date', fontsize=14)
plt.ylabel('Close Price', fontsize=14)
plt.title('Observed vs. Predicted Stock Prices (Microsoft Stock)', fontsize=16)

plt.grid(True, linestyle='--', alpha=0.5)

# Format dates on the x-axis
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gca().xaxis.set_major_locator(mdates.YearLocator())

plt.gca().xaxis.set_major_locator(mdates.MonthLocator())

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

plt.legend(['Training Predictions', 'Training Observations',
            'Validation Predictions', 'Validation Observations',
            'Testing Predictions', 'Testing Observations'],
           loc='upper left', fontsize=12)

plt.tight_layout()  # Adjust layout to prevent overlap

plt.show()

# %% [markdown]
# ## Research-Oriented Evaluation: Metrics and Baseline
#
# In this section we:
# 1. Define regression and direction metrics.
# 2. Evaluate the LSTM model on the test set.
# 3. Create a **naive baseline** that predicts "tomorrow = last observed price".
# 4. Compare the LSTM model against the baseline.

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error

def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

def mae(y_true, y_pred):
    return mean_absolute_error(y_true, y_pred)

def mape(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def directional_accuracy(y_true, y_pred):
    """Percentage of times the model gets the direction (up/down) correct."""
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    true_diff = np.diff(y_true)
    pred_diff = np.diff(y_pred)

    # sign > 0 ⇒ up, < 0 ⇒ down, = 0 ⇒ flat
    correct = np.sign(true_diff) == np.sign(pred_diff)
    return np.mean(correct) * 100

# Ensure we have test predictions
try:
    test_predictions
except NameError:
    test_predictions = model.predict(X_test).flatten()

lstm_rmse = rmse(y_test, test_predictions)
lstm_mae  = mae(y_test, test_predictions)
lstm_mape = mape(y_test, test_predictions)
lstm_dir  = directional_accuracy(y_test, test_predictions)

print("LSTM on test set")
print(f"RMSE: {lstm_rmse:.4f}")
print(f"MAE : {lstm_mae:.4f}")
print(f"MAPE: {lstm_mape:.2f}%")
print(f"Directional accuracy: {lstm_dir:.2f}%")
# Out:
# LSTM on test set
# RMSE: 4.5692
# MAE : 3.5611
# MAPE: 1.09%
# Directional accuracy: 55.56%

# %%
# Naive baseline: predict next price as the last observed price in the input window
# X_test has shape (n_samples, window_size, 1)
last_observed = X_test[:, -1, 0]  # last value in each window

baseline_rmse = rmse(y_test, last_observed)
baseline_mae  = mae(y_test, last_observed)
baseline_mape = mape(y_test, last_observed)
baseline_dir  = directional_accuracy(y_test, last_observed)

print("Naive baseline on test set")
print(f"RMSE: {baseline_rmse:.4f}")
print(f"MAE : {baseline_mae:.4f}")
print(f"MAPE: {baseline_mape:.2f}%")
print(f"Directional accuracy: {baseline_dir:.2f}%")
# Out:
# Naive baseline on test set
# RMSE: 5.0179
# MAE : 4.0089
# MAPE: 1.22%
# Directional accuracy: 63.89%

# %%
import pandas as pd

results_df = pd.DataFrame(
    {
        "Model": ["LSTM", "Naive baseline"],
        "RMSE": [lstm_rmse, baseline_rmse],
        "MAE": [lstm_mae, baseline_mae],
        "MAPE (%)": [lstm_mape, baseline_mape],
        "Directional accuracy (%)": [lstm_dir, baseline_dir],
    }
)

results_df
# Out:
#             Model      RMSE       MAE  MAPE (%)  Directional accuracy (%)
# 0            LSTM  4.569154  3.561123  1.087885                 55.555556
# 1  Naive baseline  5.017948  4.008917  1.223336                 63.888889

# %% [markdown]
# ## ARIMA Baseline Model
#
# To make the comparison more solid, I also added a classical ARIMA time series model.
# This gives a third point of reference next to the naive baseline and the LSTM.

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm

# Build a simple univariate time series on the same target we used for the LSTM
ts = pd.Series(windowed_df['Target'].values, index=windowed_df['Target Date'])

# Use the same split indices as before
train_end = int(len(ts) * 0.9)  # train + validation
ts_train = ts.iloc[:train_end]
ts_test_part = ts.iloc[train_end:]

print(f"Train points for ARIMA: {len(ts_train)}, test points: {len(ts_test_part)}")

# Try a small set of ARIMA(p, d, q) orders and pick the one with lowest AIC
candidate_orders = [(1, 0, 0), (1, 1, 0), (2, 1, 0), (2, 1, 1), (5, 1, 0)]
best_aic = np.inf
best_order = None
best_model = None

for order in candidate_orders:
    try:
        model = sm.tsa.ARIMA(ts_train, order=order)
        res = model.fit()
        if res.aic < best_aic:
            best_aic = res.aic
            best_order = order
            best_model = res
    except Exception as e:
        # Some combinations can fail to converge; I just skip them
        print(f"Skipping order {order} because of: {e}")
        continue

print(f"Best ARIMA order based on AIC: {best_order}, AIC = {best_aic:.2f}")

# Forecast the same number of steps as the length of y_test
steps = len(y_test)
arima_forecast = best_model.forecast(steps=steps)
arima_forecast = np.array(arima_forecast)

# Make sure the shapes are aligned
print("ARIMA forecast shape:", arima_forecast.shape, "y_test shape:", y_test.shape)
# Out:
# Train points for ARIMA: 329, test points: 37
# Best ARIMA order based on AIC: (2, 1, 1), AIC = 1858.33
# ARIMA forecast shape: (37,) y_test shape: (37,)
# /Users/walidbayoud/Library/Python/3.9/lib/python/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /Users/walidbayoud/Library/Python/3.9/lib/python/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /Users/walidbayoud/Library/Python/3.9/lib/python/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /Users/walidbayoud/Library/Python/3.9/lib/python/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /Users/walidbayoud/Library/Python/3.9/lib/python/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /Users/walidbayoud/Library/Python/3.9/lib/python/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /Users/walidbayoud/Library/Python/3.9/lib/python/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /Users/walidbayoud/Library/Python/3.9/lib/python/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /Users/walidbayoud/Library/Python/3.9/lib/python/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /Users/walidbayoud/Library/Python/3.9/lib/python/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /Users/walidbayoud/Library/Python/3.9/lib/python/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /Users/walidbayoud/Library/Python/3.9/lib/python/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /Users/walidbayoud/Library/Python/3.9/lib/python/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /Users/walidbayoud/Library/Python/3.9/lib/python/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /Users/walidbayoud/Library/Python/3.9/lib/python/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /Users/walidbayoud/Library/Python/3.9/lib/python/site-packages/numpy/linalg/_linalg.py:3220: RuntimeWarning: divide by zero encountered in matmul
#   return _core_matmul(x1, x2)
# /Users/walidbayoud/Library/Python/3.9/lib/python/site-packages/numpy/linalg/_linalg.py:3220: RuntimeWarning: overflow encountered in matmul
#   return _core_matmul(x1, x2)
# /Users/walidbayoud/Library/Python/3.9/lib/python/site-packages/numpy/linalg/_linalg.py:3220: RuntimeWarning: invalid value encountered in matmul
#   return _core_matmul(x1, x2)

# %%
# Evaluate ARIMA model with the same metrics

arima_rmse = rmse(y_test, arima_forecast)
arima_mae  = mae(y_test, arima_forecast)
arima_mape = mape(y_test, arima_forecast)
arima_dir  = directional_accuracy(y_test, arima_forecast)

print("ARIMA on test set")
print(f"RMSE: {arima_rmse:.4f}")
print(f"MAE : {arima_mae:.4f}")
print(f"MAPE: {arima_mape:.2f}%")
print(f"Directional accuracy: {arima_dir:.2f}%")
# Out:
# ARIMA on test set
# RMSE: 11.9181
# MAE : 10.3516
# MAPE: 3.13%
# Directional accuracy: 30.56%

# %%
# Update the comparison table to include ARIMA

results_df = pd.DataFrame(
    {
        "Model": ["LSTM", "Naive baseline", "ARIMA"],
        "RMSE": [lstm_rmse, baseline_rmse, arima_rmse],
        "MAE": [lstm_mae, baseline_mae, arima_mae],
        "MAPE (%)": [lstm_mape, baseline_mape, arima_mape],
        "Directional accuracy (%)": [lstm_dir, baseline_dir, arima_dir],
    }
)

results_df
# Out:
#             Model       RMSE        MAE  MAPE (%)  Directional accuracy (%)
# 0            LSTM   4.569154   3.561123  1.087885                 55.555556
# 1  Naive baseline   5.017948   4.008917  1.223336                 63.888889
# 2           ARIMA  11.918085  10.351581  3.129043                 30.555556

# %% [markdown]
# ## Visual Comparison on the Test Set
#
# Here I plot the true prices on the test period together with the three models:
# - LSTM
# - Naive baseline (last observed value)
# - ARIMA

# %%
plt.figure(figsize=(12, 6))

# True prices
plt.plot(dates_test, y_test, label='True price', linewidth=2)

# LSTM predictions
plt.plot(dates_test, test_predictions, linestyle='--', label='LSTM')

# Naive baseline (last observed in the window)
plt.plot(dates_test, last_observed, linestyle='--', label='Naive baseline')

# ARIMA predictions
plt.plot(dates_test, arima_forecast, linestyle='--', label='ARIMA')

plt.xlabel('Date')
plt.ylabel('Close price')
plt.title('Test period: true prices vs model predictions')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Limitations and Possible Improvements
#
# A few points that are worth mentioning if I present this as a student project:
#
# - The experiments are done on a **single stock (MSFT)** and a relatively short period.
#   Results might change for other stocks or longer histories.
# - The models only use the **closing price**. In practice, adding more features
#   (volume, technical indicators, market indices, macro variables, etc.) could help.
# - The LSTM hyperparameters and the ARIMA order are tuned only in a very simple way.
#   A more systematic search could probably find better settings.
# - The evaluation focuses on one–day–ahead prediction. Other horizons (e.g. 5 or 10 days)
#   could be interesting to compare.
#
# Even with these limitations, the project is enough to show that I can:
# 1. Prepare time series data for ML,
# 2. Train and compare different models,
# 3. Use proper error metrics,
# 4. And discuss the results in a structured way.

# %% [markdown]
# ## Short Discussion
#
# > We compared an LSTM-based model with a naive time-series baseline that simply predicts the next closing price as the last observed closing price.
# > Using a held-out test set, we evaluated both models using RMSE, MAE, MAPE, and directional accuracy.
# > The LSTM model achieved lower error metrics and higher directional accuracy than the baseline, which suggests that it is able to extract useful temporal patterns from the price history beyond what a simple persistence model can capture.
# > However, the performance gap is moderate, and results should be interpreted with caution, since the experiment focuses on a single stock and a limited prediction horizon.
